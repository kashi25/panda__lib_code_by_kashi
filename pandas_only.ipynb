# %%
from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-c76fe727-5f59-4735-a231-3bafae8e35f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c76fe727-5f59-4735-a231-3bafae8e35f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_csv('data.csv')
data.head()
# Out:
#          date  price
# 0  1950-01-01  34.73
# 1  1950-02-01  34.73
# 2  1950-03-01  34.73
# 3  1950-04-01  34.73
# 4  1950-05-01  34.73

# %%
data.shape
# Out:
# (818, 2)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    818 non-null    object
#  1   price   818 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 12.9+ KB

# %%
data.describe()
# Out:
#              price
# count   818.000000
# mean    381.194630
# std     418.855501
# min      34.490000
# 25%      35.189250
# 50%     303.033500
# 75%     422.873750
# max    1780.648000

# %%
inse = ['birds', 'animals', 'insects']

type(inse)
# Out:
# list

# %%
# list to dataFrame
pd.DataFrame(inse)
# Out:
#          0
# 0    birds
# 1  animals
# 2  insects

# %%
# to give the column name
pd.DataFrame(inse, columns = ['column_name'])
# Out:
#   column_name
# 0       birds
# 1     animals
# 2     insects

# %%
data = pd.DataFrame(inse, columns = ['column_name'])
data
# Out:
#   column_name
# 0       birds
# 1     animals
# 2     insects

# %%
# using dictionary
janawar = {'egg_giving':['pigion', 'parrot', 'dove'],
           'mammals': ['cow', 'horse', 'cat'],
           'Reptiles':['snake', 'lizard','crocodile']}

# %%
type(janawar)
# Out:
# dict

# %%
pd.DataFrame(janawar)
# Out:
#   egg_giving mammals   Reptiles
# 0     pigion     cow      snake
# 1     parrot   horse     lizard
# 2       dove     cat  crocodile

# %%
data = pd.DataFrame(janawar)

# %%
data
# Out:
#   egg_giving mammals   Reptiles
# 0     pigion     cow      snake
# 1     parrot   horse     lizard
# 2       dove     cat  crocodile

# %%
# to take particular columns
data['Reptiles']
# Out:
# 0        snake
# 1       lizard
# 2    crocodile
# Name: Reptiles, dtype: object

# %%
data.egg_giving
# Out:
# 0    pigion
# 1    parrot
# 2      dove
# Name: egg_giving, dtype: object

# %%
# to access the particular row in dataframe

data.iloc[1]
# Out:
# egg_giving    parrot
# mammals        horse
# Reptiles      lizard
# Name: 1, dtype: object

# %%
# to take first and second row of the dataframe
data.iloc[[0, 1]]
# Out:
#   egg_giving mammals Reptiles
# 0     pigion     cow    snake
# 1     parrot   horse   lizard

# %%
data
# Out:
#   egg_giving mammals   Reptiles
# 0     pigion     cow      snake
# 1     parrot   horse     lizard
# 2       dove     cat  crocodile

# %%
data
# Out:
#            date     price
# 0    1950-01-01    34.730
# 1    1950-02-01    34.730
# 2    1950-03-01    34.730
# 3    1950-04-01    34.730
# 4    1950-05-01    34.730
# ..          ...       ...
# 813  2017-10-01  1280.677
# 814  2017-11-01  1283.189
# 815  2017-12-01  1265.674
# 816  2018-01-01  1332.809
# 817  2018-02-01  1333.775
#
# [818 rows x 2 columns]

# %%
data = pd.read_csv('data.csv', index_col ='date')
data.head()
# Out:
#             price
# date
# 1950-01-01  34.73
# 1950-02-01  34.73
# 1950-03-01  34.73
# 1950-04-01  34.73
# 1950-05-01  34.73

# %%
data.loc['1950-04-01']
# Out:
# price    34.73
# Name: 1950-04-01, dtype: float64

# %%
data
# Out:
#   egg_giving mammals   Reptiles
# 0     pigion     cow      snake
# 1     parrot   horse     lizard
# 2       dove     cat  crocodile

# %%
indexes = ['one', 'two', 'three']

# %%
data.set_index([indexes], inplace=True)
data
# Out:
#       egg_giving mammals   Reptiles
# one       pigion     cow      snake
# two       parrot   horse     lizard
# three       dove     cat  crocodile

# %%
data.loc['two']
# Out:
# egg_giving    parrot
# mammals        horse
# Reptiles      lizard
# Name: two, dtype: object

# %%
# filters and rows and columns in data

# %%
data
# Out:
#       egg_giving mammals   Reptiles
# one       pigion     cow      snake
# two       parrot   horse     lizard
# three       dove     cat  crocodile

# %%
data = pd.read_csv('data.csv')
data
# Out:
#            date     price
# 0    1950-01-01    34.730
# 1    1950-02-01    34.730
# 2    1950-03-01    34.730
# 3    1950-04-01    34.730
# 4    1950-05-01    34.730
# ..          ...       ...
# 813  2017-10-01  1280.677
# 814  2017-11-01  1283.189
# 815  2017-12-01  1265.674
# 816  2018-01-01  1332.809
# 817  2018-02-01  1333.775
#
# [818 rows x 2 columns]

# %%
highest_price = (data['price'] > 1600)

# %%
highest_price
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# Name: price, Length: 818, dtype: bool

# %%
data.loc[highest_price]
# Out:
#            date     price
# 739  2011-08-01  1759.500
# 740  2011-09-01  1780.648
# 741  2011-10-01  1667.893
# 742  2011-11-01  1735.977
# 743  2011-12-01  1652.725
# 744  2012-01-01  1656.095
# 745  2012-02-01  1743.095
# 746  2012-03-01  1675.057
# 747  2012-04-01  1648.539
# 751  2012-08-01  1625.682
# 752  2012-09-01  1741.925
# 753  2012-10-01  1746.348
# 754  2012-11-01  1724.352
# 755  2012-12-01  1687.342
# 756  2013-01-01  1671.886
# 757  2013-02-01  1630.688

# %%
data['date'].unique()
# Out:
# array(['1950-01-01', '1950-02-01', '1950-03-01', '1950-04-01',
#        '1950-05-01', '1950-06-01', '1950-07-01', '1950-08-01',
#        '1950-09-01', '1950-10-01', '1950-11-01', '1950-12-01',
#        '1951-01-01', '1951-02-01', '1951-03-01', '1951-04-01',
#        '1951-05-01', '1951-06-01', '1951-07-01', '1951-08-01',
#        '1951-09-01', '1951-10-01', '1951-11-01', '1951-12-01',
#        '1952-01-01', '1952-02-01', '1952-03-01', '1952-04-01',
#        '1952-05-01', '1952-06-01', '1952-07-01', '1952-08-01',
#        '1952-09-01', '1952-10-01', '1952-11-01', '1952-12-01',
#        '1953-01-01', '1953-02-01', '1953-03-01', '1953-04-01',
#        '1953-05-01', '1953-06-01', '1953-07-01', '1953-08-01',
#        '1953-09-01', '1953-10-01', '1953-11-01', '1953-12-01',
#        '1954-01-01', '1954-02-01', '1954-03-01', '1954-04-01',
#        '1954-05-01', '1954-06-01', '1954-07-01', '1954-08-01',
#        '1954-09-01', '1954-10-01', '1954-11-01', '1954-12-01',
# ...

# %%
uniq_data = ['2018-01-01', '2014-07-01', '2013-12-01']

# %%
filt = data['date'].isin(uniq_data)

# %%
data.loc[filt]
# Out:
#            date     price
# 767  2013-12-01  1221.588
# 774  2014-07-01  1312.989
# 816  2018-01-01  1332.809

# %%
data
# Out:
#            date     price
# 0    1950-01-01    34.730
# 1    1950-02-01    34.730
# 2    1950-03-01    34.730
# 3    1950-04-01    34.730
# 4    1950-05-01    34.730
# ..          ...       ...
# 813  2017-10-01  1280.677
# 814  2017-11-01  1283.189
# 815  2017-12-01  1265.674
# 816  2018-01-01  1332.809
# 817  2018-02-01  1333.775
#
# [818 rows x 2 columns]

# %%
# updating rows and columns

# %%
data
# Out:
#            date     price
# 0    1950-01-01    34.730
# 1    1950-02-01    34.730
# 2    1950-03-01    34.730
# 3    1950-04-01    34.730
# 4    1950-05-01    34.730
# ..          ...       ...
# 813  2017-10-01  1280.677
# 814  2017-11-01  1283.189
# 815  2017-12-01  1265.674
# 816  2018-01-01  1332.809
# 817  2018-02-01  1333.775
#
# [818 rows x 2 columns]

# %%
data.columns = data.columns.str.replace('date', 'meetie')
data.head()
# Out:
#        meetie  price
# 0  1950-01-01  34.73
# 1  1950-02-01  34.73
# 2  1950-03-01  34.73
# 3  1950-04-01  34.73
# 4  1950-05-01  34.73

# %%
data.rename(columns={'price':'poisha'}, inplace=True)

# %%
data
# Out:
#          meetie    poisha
# 0    1950-01-01    34.730
# 1    1950-02-01    34.730
# 2    1950-03-01    34.730
# 3    1950-04-01    34.730
# 4    1950-05-01    34.730
# ..          ...       ...
# 813  2017-10-01  1280.677
# 814  2017-11-01  1283.189
# 815  2017-12-01  1265.674
# 816  2018-01-01  1332.809
# 817  2018-02-01  1333.775
#
# [818 rows x 2 columns]

# %%
# to modifie the value in row

data.loc[2, '1950-02-01'] = 550

# %%
data
# Out:
#          meetie    poisha  1950-02-01
# 0    1950-01-01    34.730         NaN
# 1    1950-02-01    34.730         NaN
# 2    1950-03-01    34.730       550.0
# 3    1950-04-01    34.730         NaN
# 4    1950-05-01    34.730         NaN
# ..          ...       ...         ...
# 813  2017-10-01  1280.677         NaN
# 814  2017-11-01  1283.189         NaN
# 815  2017-12-01  1265.674         NaN
# 816  2018-01-01  1332.809         NaN
# 817  2018-02-01  1333.775         NaN
#
# [818 rows x 3 columns]

# %%
data.at[2, '1950-02-01'] = 750

# %%
data.head()
# Out:
#        meetie  poisha  1950-02-01
# 0  1950-01-01   34.73         NaN
# 1  1950-02-01   34.73         NaN
# 2  1950-03-01   34.73       750.0
# 3  1950-04-01   34.73         NaN
# 4  1950-05-01   34.73         NaN
